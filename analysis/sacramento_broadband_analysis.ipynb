# %% [markdown]
# # Greater Sacramento Broadband Analysis
#
# Runs the full pipeline on cleaned data (61 ZIPs, BQ M-Lab, metro FCC/Census).
#
# CLI equivalent: `python analysis/run_analysis.py`

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path(".").resolve()))
from broadband_analysis.pipeline import run_full_analysis

results = run_full_analysis(show_plots=True)

# %%
print("Findings:", results.findings)
print("\nSpeed gap test:", results.speed_gap_test)
display(results.noise_summary)
display(results.merged.head())
display(results.correlation_matrix)
